# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option("display.notebook_repr_html", False)
#pd.set_option('display.max_rows', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8708 entries, 0 to 8707
# Columns: 225 entries, (Person.ID, 1) to (C, 15)
# dtypes: float64(105), object(120)
# memory usage: 14.9+ MB

# %%
matplotlib.rcParams['figure.figsize'] = [12, 8]

# %%
hists = df.hist([f + str(1) for f in p1_features_cont], bins=100)

# %%
#f, axarr = plt.subplots(len(p1_features_cat))
#f, ax = plt.subplots()
for i, feat in enumerate(p1_features_cat):
    col = feat + str(1)
    s = df[col].value_counts()
    plt.figure()
    s.plot(kind="bar")
    #axarr[i].bar(s.index, s.values)
    #ax.bar(df[feat + str(1)].value_counts())

# %%
# %run clean_team_data.py
# Out:
# /Users/markhashimoto/anaconda/lib/python3.5/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/markhashimoto/Documents/data_science/data_science_retreat/work/classes/mini_competition/clean_team_data.py:68: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   df.drop("Person.ID", axis=1, inplace=True)

# %%
X_team = pd.DataFrame()  
for feat in p1_features_cat:                                                   
    #print(feat)
    x = create_team_fracs_df(df, feat)                                         
    #print(x.head())
    X_team = pd.concat([X_team, x], axis=1)

# %%
X_team.head()
# Out:
#    CHIEF_INVESTIGATOR  DELEGATED_RESEARCHER  EXT_CHIEF_INVESTIGATOR  \
# 0            1.000000              0.000000                0.000000
# 1            1.000000              0.000000                0.000000
# 2            0.428571              0.142857                0.428571
# 3            0.166667              0.000000                0.500000
# 4            1.000000              0.000000                0.000000
#
#    PRINCIPAL_SUPERVISOR  STUD_CHIEF_INVESTIGATOR  HONVISIT  STUDRES  \
# 0              0.000000                 0.000000       0.0      0.0
# 1              0.000000                 0.000000       0.0      0.0
# 2              0.000000                 0.000000       0.0      0.0
# 3              0.166667                 0.166667       0.0      0.0
# 4              0.000000                 0.000000       0.0      0.0
#
#    EXTERNAL_ADVISOR  Asia Pacific  Australia    ...       58   82   40  187  \
# ...

# %%
X_team.columns
# Out:
# Index(['CHIEF_INVESTIGATOR', 'DELEGATED_RESEARCHER', 'EXT_CHIEF_INVESTIGATOR',
#        'PRINCIPAL_SUPERVISOR', 'STUD_CHIEF_INVESTIGATOR', 'HONVISIT',
#        'STUDRES', 'EXTERNAL_ADVISOR', 'Asia Pacific', 'Australia',
#        ...
#        '58', '82', '40', '187', 'Yes ', 'Less than 0', 'more than 15',
#        '>5 to 10', '>=0 to 5', '>10 to 15'],
#       dtype='object', length=154)
